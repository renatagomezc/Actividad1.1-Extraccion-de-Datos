# %% [markdown]
# <a href="https://colab.research.google.com/github/renatagomezc/Actividad1.1-Extraccion-de-Datos/blob/main/Actividad_1_1_(Extracci%C3%B3n_de_Datos).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()

# %%
df= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CVE_DOC                    1426 non-null   object
#  1   FECHA_DOC                  1426 non-null   datetime64[ns]
#  2   NOMBRE_VENDEDOR            1424 non-null   object
#  3   NOMBRE_CLIENTE             1426 non-null   object
#  4   CANT                       1426 non-null   int64
#  5   CVE_ART                    1426 non-null   object
#  6   DESCR                      1426 non-null   object
#  7   PRECIO_UNITARIO            1426 non-null   float64
#  8   COSTO_UNITARIO             1426 non-null   float64
#  9   COSTO_UNITARIO_CALCULADO   1426 non-null   float64
#  10  SUBTOTAL_PARTIDA           1426 non-null   float64
#  11  COSTO_TOTAL_CALCULADO      1426 non-null   float64
#  12  MARGEN_UNITARIO_CALCULADO  1426 non-null   float64
# ...

# %%
df.head()
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0     1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1     1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2     7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3     1    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4     2   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
#
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS**

# %% [markdown]
# Filtro 1: Se filtro por objeto, para mostrar los datos donde el Nombre_vendedor es igual a Leticia Ramirez Hernandez

# %%
#Filtro por objeto 
filtro1=df[df["NOMBRE_VENDEDOR"] == "LETICIA RAMIREZ HERNANDEZ"]
filtro1
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 4               PÚBLICO EN GENERAL     2       BP00242
# 5               PÚBLICO EN GENERAL     2       BP00243
# 7        ANA BARBARA CRUZ PALACIOS     3        TP0001
# ...

# %% [markdown]
# Filtro 2: Se filtro por filas consecutivas para mostrar únicamente de las filas 2 a la 7.

# %%
#Filtro por filas
filtro2= df.iloc[2:8,: ]   
filtro2
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6  F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7  F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
#
#                         NOMBRE_CLIENTE  CANT  CVE_ART  \
# 2            ANA BARBARA CRUZ PALACIOS     7   TP0007
# 3                 OMAR RODRIGUEZ GOMEZ     1   TP0001
# 4                   PÚBLICO EN GENERAL     2  BP00242
# 5                   PÚBLICO EN GENERAL     2  BP00243
# 6  AIRBUS HELICOPTERS MEXICO QUERETARO     1  RP00165
# 7            ANA BARBARA CRUZ PALACIOS     3   TP0001
#
#                                      DESCR  PRECIO_UNITARIO  COSTO_UNITARIO  \
# 2     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61          177.68
# 3     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00           38.96
# ...

# %% [markdown]
# Filtro 3: Se filtro por columnas no consecutivas para poder ver juntas las columnas de fecha_doc, nombre_cliente, cantidad y subtotal_partida.
#
# Siendo las columnas 1,3,4,10

# %%
#Filtro por columnas
filtro3=df.iloc[ : , [1, 3, 4,10]]  
filtro3
# Out:
#       FECHA_DOC                NOMBRE_CLIENTE  CANT  SUBTOTAL_PARTIDA
# 0    2022-01-05            PÚBLICO EN GENERAL     1            434.48
# 1    2022-01-05  JUAN ANTONIO RESENDIZ UGALDE     1           1264.05
# 2    2022-01-05     ANA BARBARA CRUZ PALACIOS     7           3861.29
# 3    2022-01-05          OMAR RODRIGUEZ GOMEZ     1            140.00
# 4    2022-01-05            PÚBLICO EN GENERAL     2            344.83
# ...         ...                           ...   ...               ...
# 1421 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ     6           4272.00
# 1422 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ     6           4311.60
# 1423 2022-12-23          SEVEN DAYS ALL SPORT     3           6547.05
# 1424 2022-12-23           REVUELTA MONTECARLO     1           5909.84
# 1425 2022-12-23                CPEG SOLUTIONS    10          14060.00
#
# [1426 rows x 4 columns]

# %%
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9400d103-78e8-4d19-96ce-1c9056f03c6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9400d103-78e8-4d19-96ce-1c9056f03c6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col=1)
df1
# Out:
#            CVE_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# FECHA_DOC
# 2022-01-05  F37034  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 2022-01-05  F37036  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2022-01-05  F37041   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 2022-01-05  F37042   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 2022-01-05  F37043  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# ...            ...                        ...                           ...
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39835  LETICIA RAMIREZ HERNANDEZ          SEVEN DAYS ALL SPORT
# 2022-12-23  F39837  LETICIA RAMIREZ HERNANDEZ           REVUELTA MONTECARLO
# 2022-12-23  F39838         AARON NUÑO CORDOVA                CPEG SOLUTIONS
#
# ...

# %% [markdown]
# Filtro 4: Se filtro un filtro de filas con columnas. Mostrando únicamente las filas que tenga la fecha de doc (que es el índice) igual a 2022-11-22 y 2022-12-23. Mostrando la columna de subtotal_partida.

# %%
filtro4=df1.loc[["2022-11-22","'2022-12-23"], ["SUBTOTAL_PARTIDA"]]
filtro4
# Out:
#             SUBTOTAL_PARTIDA
# FECHA_DOC
# 2022-11-22           4850.00
# 2022-11-22            630.00
# 2022-11-22           8452.40
# 2022-12-23          12500.00
# 2022-12-23           9486.35
# 2022-12-23           1530.00
# 2022-12-23          11328.00
# 2022-12-23           1317.45
# 2022-12-23           1851.64
# 2022-12-23           3821.00
# 2022-12-23           4040.84
# 2022-12-23           2354.14
# 2022-12-23           4272.00
# 2022-12-23           4311.60
# 2022-12-23           6547.05
# 2022-12-23           5909.84
# 2022-12-23          14060.00

# %% [markdown]
# Filtro 5: Filtramos por cabecera para que muestre los primero 8 filas.

# %%
filtro5=df.head(8)
filtro5
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6  F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7  F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
#
#                         NOMBRE_CLIENTE  CANT   CVE_ART  \
# 0                   PÚBLICO EN GENERAL     1  TUE00244
# 1         JUAN ANTONIO RESENDIZ UGALDE     1  TUA00028
# 2            ANA BARBARA CRUZ PALACIOS     7    TP0007
# 3                 OMAR RODRIGUEZ GOMEZ     1    TP0001
# 4                   PÚBLICO EN GENERAL     2   BP00242
# 5                   PÚBLICO EN GENERAL     2   BP00243
# 6  AIRBUS HELICOPTERS MEXICO QUERETARO     1   RP00165
# 7            ANA BARBARA CRUZ PALACIOS     3    TP0001
#
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**

# %% [markdown]
# Filtro 6: Filtre por comparación, para obtener los datos donde el valor en subtotal_partida sea mayor a 77000

# %%
filtro6=df[df["SUBTOTAL_PARTIDA"] > 77000]
filtro6
# Out:
#     CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR         NOMBRE_CLIENTE  \
# 403  F37777 2022-03-31             ALFREDO CANELA  CLAVOS NACIONALES C.N
# 615  F38221 2022-05-24  LETICIA RAMIREZ HERNANDEZ          TERMOFORMATEC
#
#      CANT    CVE_ART                                     DESCR  \
# 403    60  BOBINA001     BOBINA CAL.8 DSD C/TERMINALES EN INOX
# 615    60   CAS00080  CAS INOX 18.5MMØX205MM 950W 440V EXT30CM
#
#      PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 403          1299.32           340.8                    340.80
# 615          1296.00             0.0                    244.07
#
#      SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# 403           77959.2               20448.01                     958.52
# 615           77760.0               14643.92                    1051.93
#
#      MARGEN_TOTAL_CALCULADO
# 403                57511.19
# 615                63116.08

# %% [markdown]
# **FILTROS BASICOS CON CONETORES LOGICOS**

# %% [markdown]
# Filtro 7: Hice dos filtros. Usando una condición and. Donde se deben de cumplir el filtro que subtotal_partida sea mayor a 77000 y que la fehca_doc sea igual a 2022-05-24

# %%
#Filtro Y Tiene que cumplir las dos condiciones
filtro7=df[(df["SUBTOTAL_PARTIDA"] > 77000) & (df["FECHA_DOC"] == "2022-05-24")]
filtro7
# Out:
#     CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR NOMBRE_CLIENTE  CANT  \
# 615  F38221 2022-05-24  LETICIA RAMIREZ HERNANDEZ  TERMOFORMATEC    60
#
#       CVE_ART                                     DESCR  PRECIO_UNITARIO  \
# 615  CAS00080  CAS INOX 18.5MMØX205MM 950W 440V EXT30CM           1296.0
#
#      COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 615             0.0                    244.07           77760.0
#
#      COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  MARGEN_TOTAL_CALCULADO
# 615               14643.92                    1051.93                63116.08

# %% [markdown]
# Filtro 8: Ahora filtre con una condición or. Donde se muestren los dados donde el subtotal_partida sea mayor a 77000 o el que la fehca_doc sea igual a 2022-05-24

# %%
#Filtro o
filtro8=df[(df["SUBTOTAL_PARTIDA"] > 77000)| (df["FECHA_DOC"] == "2022-05-24")]
filtro8
# Out:
#     CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR         NOMBRE_CLIENTE  \
# 403  F37777 2022-03-31             ALFREDO CANELA  CLAVOS NACIONALES C.N
# 615  F38221 2022-05-24  LETICIA RAMIREZ HERNANDEZ          TERMOFORMATEC
#
#      CANT    CVE_ART                                     DESCR  \
# 403    60  BOBINA001     BOBINA CAL.8 DSD C/TERMINALES EN INOX
# 615    60   CAS00080  CAS INOX 18.5MMØX205MM 950W 440V EXT30CM
#
#      PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 403          1299.32           340.8                    340.80
# 615          1296.00             0.0                    244.07
#
#      SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# 403           77959.2               20448.01                     958.52
# 615           77760.0               14643.92                    1051.93
#
#      MARGEN_TOTAL_CALCULADO
# 403                57511.19
# 615                63116.08

# %% [markdown]
# Filtro 9: Ahora es un filtro con conidicón not. Donde muestra los datos donde el subtotal_partida no es mayor a 77000 y que la fehca_doc no es igual a 2022-05-24

# %%
#Filtro not
filtro9=df[~(df["SUBTOTAL_PARTIDA"] > 77000) & ~(df["FECHA_DOC"] == "2022-05-24")]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
#Convertir archivo filtrado a CSV
filtro1.to_csv("Entregable1.csv")
filtro2.to_csv("Entregable2.csv")
filtro3.to_csv("Entregable3.csv")
filtro4.to_csv("Entregable4.csv")
filtro5.to_csv("Entregable5.csv")
filtro6.to_csv("Entregable6.csv")
filtro7.to_csv("Entregable7.csv")
filtro8.to_csv("Entregable8.csv")
filtro9.to_csv("Entregable9.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable1.csv")
files.download("Entregable2.csv")
files.download("Entregable3.csv")
files.download("Entregable4.csv")
files.download("Entregable5.csv")
files.download("Entregable6.csv")
files.download("Entregable7.csv")
files.download("Entregable8.csv")
files.download("Entregable9.csv")
